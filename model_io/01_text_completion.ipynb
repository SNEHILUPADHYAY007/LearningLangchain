# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import GoogleGenerativeAI

env_path = '../.env'
# Out:
# /Users/snehilupadhyay/Developer/LearningLangchain/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# ### Setting up the Environment keys for API req.

# %%
load_dotenv(override=True, dotenv_path=env_path)

google_api_key = os.getenv("GOOGLE_API_KEY")

if google_api_key:
    print("API Key loaded successfully.")
    llm = GoogleGenerativeAI(
            model="gemini-2.5-flash"
        )
    print("GoogleGenerativeAI LLM initialized.")
else:
    print("Failed to load API Key.")
# Out:
# API Key loaded successfully.
# GoogleGenerativeAI LLM initialized.

# %%
llm.invoke("A Boy is sitting on the ...")
# Out:
# '...**chair.**\n...**sofa.**\n...**floor.**\n...**bench.**\n...**bed.**\n...**ground.**\n\nHow would you like to complete the sentence?'
