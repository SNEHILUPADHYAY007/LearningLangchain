# %%
from langchain_community.document_loaders import CSVLoader, BSHTMLLoader, PyPDFLoader

csvData = CSVLoader("data/data/sample.csv").load() 
print(csvData[0].page_content)
# Out:
# /Users/snehilupadhyay/Developer/LearningLangchain/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# id: 1
# name: Alice
# feedback: The UI is very intuitive

# %%
htmlData = BSHTMLLoader("data/data/sample.html").load()
print(htmlData[0].page_content)
# Out:
# LangChain HTML Test
#
#
# Welcome to LangChain
# This is a simple HTML document.
# It is used to test HTML document loaders.

# %%
pdfData = PyPDFLoader("data/data/sample.pdf").load()
print(pdfData[0].page_content)
# Out:
# LangChain PDF Test Document
# This document is used to test PDF loading.
# LangChain helps load and process documents easily.
